# %%
from PIL import Image
import matplotlib.pyplot as plt
import happybase
import numpy as np

# %%
connection = happybase.Connection('hadoop-master', port=9090)
table = connection.table('diabetic-retinopathy')

# %%
row = table.row('18203_right')

# %%
image = Image.frombytes('RGB', (224, 224), row[b'data:image'], 'raw')

# %%
for key, data in table.rows([b'data:image']):
    print(key, data)  # prints row key and data for each rowz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/dat500/lib/python3.7/site-packages/thriftpy2/protocol/cybin/cybin.pyx in cybin.write_struct()
#
# ~/anaconda3/envs/dat500/lib/python3.7/site-packages/thriftpy2/protocol/cybin/cybin.pyx in cybin.c_write_val()
#
# ~/anaconda3/envs/dat500/lib/python3.7/site-packages/thriftpy2/protocol/cybin/cybin.pyx in cybin.write_list()
#
# ~/anaconda3/envs/dat500/lib/python3.7/site-packages/thriftpy2/protocol/cybin/cybin.pyx in cybin.c_write_val()
#
# TypeError: Expected bytes, got int
#
# During handling of the above exception, another exception occurred:
#
# TDecodeException                          Traceback (most recent call last)
# <ipython-input-55-d1b8ff399eca> in <module>
# ----> 1 for key, data in table.rows(row[b'data:image']):
#       2     print(key, data)  # prints row key and data for each rowz
#
# ...

# %%
plt.imshow(data)
plt.show()
